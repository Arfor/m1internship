# %%
# Tutorial 2.2.2. Transport through a quantum wire
# ================================================
#
# Physics background
# ------------------
#  Conductance of a quantum wire; subbands
#
# Kwant features highlighted
# --------------------------
#  - Builder for setting up transport systems easily
#  - Making scattering region and leads
#  - Using the simple sparse solver for computing Landauer conductance

from matplotlib import pyplot
import kwant

# First, define the tight-binding system
sys = kwant.Builder()

a = 1
lat = kwant.lattice.chain(a)

t = 1.0
m = 0
d = 1.0
L = 25

# %%
# Define the scattering region
for i in range(L):
        # On-site Hamiltonian
        sys[lat(i)] = 4 * t

        # Hopping term
        if i > 0:
            sys[lat(i), lat(i, i-1)] = t

#         # Hopping in x-direction
#         if i > 0:
#             sys[lat(i, j), lat(i - 1, j)] = -t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\lps\lib\site-packages\kwant\builder.py in __new__(cls, family, tag, _i_know_what_i_do)
#      74         try:
# ---> 75             tag = family.normalize_tag(tag)
#      76         except (TypeError, ValueError) as e:
#
# C:\ProgramData\Anaconda3\envs\lps\lib\site-packages\kwant\lattice.py in normalize_tag(self, tag)
#     475         if len(tag) != self.lattice_dim:
# --> 476             raise ValueError("Dimensionality mismatch.")
#     477         return tag
#
# ValueError: Dimensionality mismatch.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-dbf8b153e52a> in <module>
#       6         # Hopping in y-direction
#       7         if i > 0:
# ----> 8             sys[lat(i), lat(i, i-1)] = -t
#       9
#      10 #         # Hopping in x-direction
#
# C:\ProgramData\Anaconda3\envs\lps\lib\site-packages\kwant\builder.py in __call__(self, *tag)
#     194             raise ValueError('Use site_family(1, 2) instead of '
#     195                              'site_family((1, 2))!')
# --> 196         return Site(self, tag)
#     197
#     198
#
# C:\ProgramData\Anaconda3\envs\lps\lib\site-packages\kwant\builder.py in __new__(cls, family, tag, _i_know_what_i_do)
#      76         except (TypeError, ValueError) as e:
#      77             msg = 'Tag {0} is not allowed for site family {1}: {2}'
# ---> 78             raise type(e)(msg.format(repr(tag), repr(family), e.args[0]))
#      79         return tuple.__new__(cls, (family, tag))
#      80
#
# ValueError: Tag (1, 0) is not allowed for site family kwant.lattice.Monatomic([[1.0]], [0.0], '', None): Dimensionality mismatch.

# %%
# Then, define and attach the leads:

# First the lead to the left
# (Note: TranslationalSymmetry takes a real-space vector)
sym_left_lead = kwant.TranslationalSymmetry((-a, 0))
left_lead = kwant.Builder(sym_left_lead)
#%%
for j in range(W):
    left_lead[lat(0, j)] = 4 * t
    if j > 0:
        left_lead[lat(0, j), lat(0, j - 1)] = -t
    left_lead[lat(1, j), lat(0, j)] = -t

sys.attach_lead(left_lead)

# Then the lead to the right
sym_right_lead = kwant.TranslationalSymmetry((a, 0))
right_lead = kwant.Builder(sym_right_lead)

for j in range(W):
    right_lead[lat(0, j)] = 4 * t
    if j > 0:
        right_lead[lat(0, j), lat(0, j - 1)] = -t
    right_lead[lat(1, j), lat(0, j)] = -t

sys.attach_lead(right_lead)

# Plot it, to make sure it's OK
kwant.plot(sys)

# Finalize the system
sys = sys.finalized()

# Now that we have the system, we can compute conductance
energies = []
data = []
for ie in range(100):
    energy = ie * 0.01

    # compute the scattering matrix at a given energy
    smatrix = kwant.smatrix(sys, energy)

    # compute the transmission probability from lead 0 to
    # lead 1
    energies.append(energy)
    data.append(smatrix.transmission(1, 0))

# Use matplotlib to write output
# We should see conductance steps
pyplot.figure()
pyplot.plot(energies, data)
pyplot.xlabel("energy [t]")
pyplot.ylabel("conductance [e^2/h]")
pyplot.show()
